# %%
# Imports
import sys
from pathlib import Path

# Resolve project root and ensure it's on sys.path
ROOT = Path.cwd().resolve()
for _ in range(5):
    if (ROOT / "pyproject.toml").exists() or (ROOT / "raw_data").exists():
        break
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from katebatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from utils import discretize_preprocess
from katebatic.models.tabddpm.models import Tabddpm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 16
#      14 from katebatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
#      15 from utils import discretize_preprocess
# ---> 16 from katebatic.models.tabddpm import Tabddpm
#
# File ~/Documents/Work/Katebatic/katebatic/katebatic/models/tabddpm/__init__.py:2
#       1 """Module for Tabddpm model."""
# ----> 2 from .models import Tabddpm
#       4 __all__ = ["Tabddpm"]
#
# File ~/Documents/Work/Katebatic/katebatic/katebatic/models/tabddpm/models.py:19
#      16 from katebatic.models.base_model import Model
#      18 # Core TabDDPM pieces (from your provided codebase)
# ---> 19 from tabddpm.model.gaussian_multinomial_diffusion import GaussianMultinomialDiffusion
#      20 from tabddpm.model.modules import MLPDiffusion  # You can switch to ResNetDiffusion if needed
#      23 ArrayLike = Union[pd.Series, pd.DataFrame, np.ndarray, Sequence]
#
# ModuleNotFoundError: No module named 'tabddpm'

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "car.csv"
output_path = ROOT / "discretized_data" / "car.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# %%
# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "car")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "car" / "tabddpm")

pipeline = TrainTestSplitPipeline(model=Tabddpm)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
)
print(result)
