# %% [markdown]
# # flow-VAE Data Generation

# %%
from katabatic.models.flowvae.models import FlowVAEModel
from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from utils import discretize_preprocess

# %%
dataset_path = "raw_data/shuttle.csv"
output_path = "discretized_data/shuttle.csv"
discretize_preprocess(dataset_path, output_path)
# Out:
# Preprocessing: raw_data/shuttle.csv
# Saved preprocessed discrete dataset to: discretized_data/shuttle.csv

# %%
datasets = ['car', 'adult', 'magic', 'nursery', 'shuttle']

for dataset in datasets:
    input_csv = f'discretized_data/{dataset}.csv'
    output_dir = f'sample_data/{dataset}'
    
    pipeline = TrainTestSplitPipeline(model=FlowVAEModel)
    pipeline.run(
        input_csv=input_csv,
        output_dir=output_dir,
        synthetic_dir=f'synthetic/{dataset}/flowvae',
        real_test_dir=f'sample_data/{dataset}'
    )
# Out:
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# [FlowVAE] Training on 1382 rows, 25 encoded dimensions, device=cpu.
# [FlowVAE] Epoch 1/50 - loss=6.5228
# [FlowVAE] Epoch 10/50 - loss=5.2857
# [FlowVAE] Epoch 20/50 - loss=4.3961
# [FlowVAE] Epoch 30/50 - loss=3.7509
# [FlowVAE] Epoch 40/50 - loss=3.3687
# [FlowVAE] Epoch 50/50 - loss=3.1294
# [FlowVAE] Training finished in 0.66 seconds.
# [FlowVAE] Synthetic data saved:
#   X -> synthetic/car/flowvae/x_synth.csv
#   y -> synthetic/car/flowvae/y_synth.csv
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/xgboost/training.py:200: UserWarning: [11:06:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/car/flowvae_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6994
# F1 Score: 0.5757
#
# MLP:
# Accuracy: 0.6994
# F1 Score: 0.5757
#
# RF:
# Accuracy: 0.6445
# F1 Score: 0.5889
#
# XGBoost:
# Accuracy: 0.6069
# F1 Score: 0.5756
# Loaded data with shape: (32561, 15)
# Saved train/test full data
# Train size: (26048, 15), Test size: (6513, 15)
# Train label distribution:
#  class
# 0    0.759175
# 1    0.240825
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.759251
# 1    0.240749
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (26048, 14) (26048,)
# Test shape: (6513, 14) (6513,)
# [FlowVAE] Training on 26048 rows, 89 encoded dimensions, device=cpu.
# [FlowVAE] Epoch 1/50 - loss=10.0356
# [FlowVAE] Epoch 10/50 - loss=4.9577
# [FlowVAE] Epoch 20/50 - loss=4.0446
# [FlowVAE] Epoch 30/50 - loss=3.4377
# [FlowVAE] Epoch 40/50 - loss=2.9884
# [FlowVAE] Epoch 50/50 - loss=2.6932
# [FlowVAE] Training finished in 12.56 seconds.
# [FlowVAE] Synthetic data saved:
#   X -> synthetic/adult/flowvae/x_synth.csv
#   y -> synthetic/adult/flowvae/y_synth.csv
#
# Results saved to: Results/adult/flowvae_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7593
# F1 Score: 0.6553
# AUC: 0.5102
#
# MLP:
# Accuracy: 0.7593
# F1 Score: 0.6553
# AUC: 0.3872
#
# RF:
# Accuracy: 0.7517
# F1 Score: 0.6549
# AUC: 0.4799
#
# XGBoost:
# Accuracy: 0.6688
# F1 Score: 0.6260
# AUC: 0.4305
# Loaded data with shape: (19020, 11)
# Saved train/test full data
# Train size: (15216, 11), Test size: (3804, 11)
# Train label distribution:
#  class
# 0    0.648396
# 1    0.351604
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.648265
# 1    0.351735
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (15216, 10) (15216,)
# Test shape: (3804, 10) (3804,)
# [FlowVAE] Training on 15216 rows, 77 encoded dimensions, device=cpu.
# [FlowVAE] Epoch 1/50 - loss=7.4773
# [FlowVAE] Epoch 10/50 - loss=3.8341
# [FlowVAE] Epoch 20/50 - loss=3.0011
# [FlowVAE] Epoch 30/50 - loss=2.4504
# [FlowVAE] Epoch 40/50 - loss=2.0215
# [FlowVAE] Epoch 50/50 - loss=1.6822
# [FlowVAE] Training finished in 7.55 seconds.
# [FlowVAE] Synthetic data saved:
#   X -> synthetic/magic/flowvae/x_synth.csv
#   y -> synthetic/magic/flowvae/y_synth.csv
#
# Results saved to: Results/magic/flowvae_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6483
# F1 Score: 0.5099
# AUC: 0.4967
#
# MLP:
# Accuracy: 0.6485
# F1 Score: 0.5129
# AUC: 0.4317
#
# RF:
# Accuracy: 0.6438
# F1 Score: 0.5231
# AUC: 0.4459
#
# XGBoost:
# Accuracy: 0.5542
# F1 Score: 0.5615
# AUC: 0.4879
# Loaded data with shape: (12960, 9)
# Saved train/test full data
# Train size: (10368, 9), Test size: (2592, 9)
# Train label distribution:
#  8
# 0    0.333333
# 1    0.329186
# 3    0.312018
# 4    0.025270
# 2    0.000193
# Name: proportion, dtype: float64
# Test label distribution:
#  8
# 0    0.333333
# 1    0.329090
# 3    0.312114
# 4    0.025463
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (10368, 8) (10368,)
# Test shape: (2592, 8) (2592,)
# [FlowVAE] Training on 10368 rows, 32 encoded dimensions, device=cpu.
# [FlowVAE] Epoch 1/50 - loss=7.2303
# [FlowVAE] Epoch 10/50 - loss=4.2074
# [FlowVAE] Epoch 20/50 - loss=3.4747
# [FlowVAE] Epoch 30/50 - loss=2.9724
# [FlowVAE] Epoch 40/50 - loss=2.5709
# [FlowVAE] Epoch 50/50 - loss=2.2246
# [FlowVAE] Training finished in 5.00 seconds.
# [FlowVAE] Synthetic data saved:
#   X -> synthetic/nursery/flowvae/x_synth.csv
#   y -> synthetic/nursery/flowvae/y_synth.csv
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/xgboost/training.py:200: UserWarning: [11:07:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/nursery/flowvae_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.2932
# F1 Score: 0.2317
#
# MLP:
# Accuracy: 0.3476
# F1 Score: 0.3326
#
# RF:
# Accuracy: 0.2874
# F1 Score: 0.2746
#
# XGBoost:
# Accuracy: 0.2658
# F1 Score: 0.2394
# Loaded data with shape: (58000, 10)
# Saved train/test full data
# Train size: (46400, 10), Test size: (11600, 10)
# Train label distribution:
#  class
# 0    0.785970
# 3    0.153491
# 4    0.056336
# 2    0.002953
# 1    0.000862
# 6    0.000216
# 5    0.000172
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.785948
# 3    0.153534
# 4    0.056293
# 2    0.002931
# 1    0.000862
# 6    0.000259
# 5    0.000172
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (46400, 9) (46400,)
# Test shape: (11600, 9) (11600,)
# [FlowVAE] Training on 46400 rows, 89 encoded dimensions, device=cpu.
# [FlowVAE] Epoch 1/50 - loss=7.0166
# [FlowVAE] Epoch 10/50 - loss=3.0526
# [FlowVAE] Epoch 20/50 - loss=1.9572
# [FlowVAE] Epoch 30/50 - loss=1.2734
# [FlowVAE] Epoch 40/50 - loss=0.8072
# [FlowVAE] Epoch 50/50 - loss=0.4346
# [FlowVAE] Training finished in 23.46 seconds.
# [FlowVAE] Synthetic data saved:
#   X -> synthetic/shuttle/flowvae/x_synth.csv
#   y -> synthetic/shuttle/flowvae/y_synth.csv
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/xgboost/training.py:200: UserWarning: [11:07:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/shuttle/flowvae_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7722
# F1 Score: 0.6865
#
# MLP:
# Accuracy: 0.6334
# F1 Score: 0.6346
#
# RF:
# Accuracy: 0.7859
# F1 Score: 0.6917
#
# XGBoost:
# Accuracy: 0.7859
# F1 Score: 0.6917
