# %% [markdown]
# # TabKDE Data Generation

# %%
from katabatic.models.tabkde.models import TabKDEModel
from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from utils import discretize_preprocess

# %%
dataset_path = "raw_data/shuttle.csv"
output_path = "discretized_data/shuttle.csv"
discretize_preprocess(dataset_path, output_path)
# Out:
# Preprocessing: raw_data/shuttle.csv
# Saved preprocessed discrete dataset to: discretized_data/shuttle.csv

# %%
datasets = ['car', 'adult', 'magic', 'nursery', 'shuttle']

for dataset in datasets:
    input_csv = f'discretized_data/{dataset}.csv'
    output_dir = f'sample_data/{dataset}'
    
    pipeline = TrainTestSplitPipeline(model=TabKDEModel)
    pipeline.run(
        input_csv=input_csv,
        output_dir=output_dir,
        synthetic_dir=f'synthetic/{dataset}/tabkde',
        real_test_dir=f'sample_data/{dataset}'
    )
# Out:
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/xgboost/training.py:200: UserWarning: [10:12:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/car/tabkde_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6994
# F1 Score: 0.5757
#
# MLP:
# Accuracy: 0.6994
# F1 Score: 0.5757
#
# RF:
# Accuracy: 0.6272
# F1 Score: 0.5652
#
# XGBoost:
# Accuracy: 0.6098
# F1 Score: 0.5653
# Loaded data with shape: (32561, 15)
# Saved train/test full data
# Train size: (26048, 15), Test size: (6513, 15)
# Train label distribution:
#  class
# 0    0.759175
# 1    0.240825
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.759251
# 1    0.240749
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (26048, 14) (26048,)
# Test shape: (6513, 14) (6513,)
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Results saved to: Results/adult/tabkde_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7593
# F1 Score: 0.6553
# AUC: 0.5633
#
# MLP:
# Accuracy: 0.4417
# F1 Score: 0.4728
# AUC: 0.5162
#
# RF:
# Accuracy: 0.7556
# F1 Score: 0.6538
# AUC: 0.4813
#
# XGBoost:
# Accuracy: 0.4382
# F1 Score: 0.4784
# AUC: 0.3520
# Loaded data with shape: (19020, 11)
# Saved train/test full data
# Train size: (15216, 11), Test size: (3804, 11)
# Train label distribution:
#  class
# 0    0.648396
# 1    0.351604
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.648265
# 1    0.351735
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (15216, 10) (15216,)
# Test shape: (3804, 10) (3804,)
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Results saved to: Results/magic/tabkde_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6483
# F1 Score: 0.5099
# AUC: 0.6449
#
# MLP:
# Accuracy: 0.6554
# F1 Score: 0.5402
# AUC: 0.5100
#
# RF:
# Accuracy: 0.6354
# F1 Score: 0.5977
# AUC: 0.5989
#
# XGBoost:
# Accuracy: 0.5923
# F1 Score: 0.5894
# AUC: 0.5769
# Loaded data with shape: (12960, 9)
# Saved train/test full data
# Train size: (10368, 9), Test size: (2592, 9)
# Train label distribution:
#  8
# 0    0.333333
# 1    0.329186
# 3    0.312018
# 4    0.025270
# 2    0.000193
# Name: proportion, dtype: float64
# Test label distribution:
#  8
# 0    0.333333
# 1    0.329090
# 3    0.312114
# 4    0.025463
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (10368, 8) (10368,)
# Test shape: (2592, 8) (2592,)
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/xgboost/training.py:200: UserWarning: [10:13:08] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/nursery/tabkde_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.3688
# F1 Score: 0.3602
#
# MLP:
# Accuracy: 0.3183
# F1 Score: 0.3139
#
# RF:
# Accuracy: 0.3179
# F1 Score: 0.3157
#
# XGBoost:
# Accuracy: 0.3048
# F1 Score: 0.3025
# Loaded data with shape: (58000, 10)
# Saved train/test full data
# Train size: (46400, 10), Test size: (11600, 10)
# Train label distribution:
#  class
# 0    0.785970
# 3    0.153491
# 4    0.056336
# 2    0.002953
# 1    0.000862
# 6    0.000216
# 5    0.000172
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.785948
# 3    0.153534
# 4    0.056293
# 2    0.002931
# 1    0.000862
# 6    0.000259
# 5    0.000172
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (46400, 9) (46400,)
# Test shape: (11600, 9) (11600,)
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/xgboost/training.py:200: UserWarning: [10:13:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/shuttle/tabkde_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7859
# F1 Score: 0.6917
#
# MLP:
# Accuracy: 0.7859
# F1 Score: 0.6917
#
# RF:
# Accuracy: 0.7514
# F1 Score: 0.6783
#
# XGBoost:
# Accuracy: 0.7278
# F1 Score: 0.6754
