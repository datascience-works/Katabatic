# %% [markdown]
# # MEG Data Generation

# %%
from katabatic.models.meg.models import MEGModel
from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from utils import discretize_preprocess

# %%
dataset_path = "raw_data/shuttle.csv"
output_path = "discretized_data/shuttle.csv"
discretize_preprocess(dataset_path, output_path)
# Out:
# Preprocessing: raw_data/shuttle.csv
# Saved preprocessed discrete dataset to: discretized_data/shuttle.csv

# %%
datasets = ['car']

for dataset in datasets:
    input_csv = f'discretized_data/{dataset}.csv'
    output_dir = f'sample_data/{dataset}'
    
    pipeline = TrainTestSplitPipeline(model=MEGModel)
    pipeline.run(
        input_csv=input_csv,
        output_dir=output_dir,
        synthetic_dir=f'synthetic/{dataset}/meg',
        real_test_dir=f'sample_data/{dataset}'
    )
# Out:
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# [MEG][class=0] Epoch 20/100 | Loss: 0.3233
# [MEG][class=0] Epoch 40/100 | Loss: 0.2178
# [MEG][class=0] Epoch 60/100 | Loss: 0.2734
# [MEG][class=0] Epoch 80/100 | Loss: 0.2526
# [MEG][class=0] Epoch 100/100 | Loss: 0.7238
# [MEG][class=1] Epoch 20/100 | Loss: 0.0442
# [MEG][class=1] Epoch 40/100 | Loss: 0.0428
# [MEG][class=1] Epoch 60/100 | Loss: 0.6017
# [MEG][class=1] Epoch 80/100 | Loss: 0.6454
# [MEG][class=1] Epoch 100/100 | Loss: 0.1414
# [MEG][class=2] Epoch 20/100 | Loss: 0.5540
# [MEG][class=2] Epoch 40/100 | Loss: 0.3260
# [MEG][class=2] Epoch 60/100 | Loss: 0.4635
# [MEG][class=2] Epoch 80/100 | Loss: 0.2209
# [MEG][class=2] Epoch 100/100 | Loss: 0.2276
# [MEG][class=3] Epoch 20/100 | Loss: 0.1106
# [MEG][class=3] Epoch 40/100 | Loss: 0.0496
# [MEG][class=3] Epoch 60/100 | Loss: 0.2705
# [MEG][class=3] Epoch 80/100 | Loss: 0.1059
# [MEG][class=3] Epoch 100/100 | Loss: 0.2199
# MEG synthetic data saved to: synthetic/car/meg
#
# Results saved to: Results/car/meg_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.3699
# F1 Score: 0.4214
#
# MLP:
# Accuracy: 0.4884
# F1 Score: 0.5170
#
# RF:
# Accuracy: 0.5838
# F1 Score: 0.6540
#
# XGBoost:
# Accuracy: 0.6214
# F1 Score: 0.6201
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/xgboost/training.py:200: UserWarning: [10:58:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
