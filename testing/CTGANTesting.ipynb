# %% [markdown]
# # CTGAN Data Generation

# %%
from katabatic.models.ctgan.models import CTGANModel
from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from utils import discretize_preprocess

# %%
dataset_path = "raw_data/shuttle.csv"
output_path = "discretized_data/shuttle.csv"
discretize_preprocess(dataset_path, output_path)
# Out:
# Preprocessing: raw_data/shuttle.csv
# Saved preprocessed discrete dataset to: discretized_data/shuttle.csv

# %%
datasets = ['car', 'adult', 'magic', 'nursery', 'shuttle']

for dataset in datasets:
    input_csv = f'discretized_data/{dataset}.csv'
    output_dir = f'sample_data/{dataset}'
    
    pipeline = TrainTestSplitPipeline(model=CTGANModel)
    pipeline.run(
        input_csv=input_csv,
        output_dir=output_dir,
        synthetic_dir=f'synthetic/{dataset}/ctgan',
        real_test_dir=f'sample_data/{dataset}'
    )
# Out:
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# [CTGAN] Synthetic data saved:
#   X -> synthetic/car/ctgan/x_synth.csv
#   y -> synthetic/car/ctgan/y_synth.csv
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/xgboost/training.py:200: UserWarning: [17:23:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/car/ctgan_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6994
# F1 Score: 0.5757
#
# MLP:
# Accuracy: 0.6936
# F1 Score: 0.5729
#
# RF:
# Accuracy: 0.5867
# F1 Score: 0.5478
#
# XGBoost:
# Accuracy: 0.5896
# F1 Score: 0.5684
# Loaded data with shape: (32561, 15)
# Saved train/test full data
# Train size: (26048, 15), Test size: (6513, 15)
# Train label distribution:
#  class
# 0    0.759175
# 1    0.240825
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.759251
# 1    0.240749
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (26048, 14) (26048,)
# Test shape: (6513, 14) (6513,)
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but QuantileTransformer was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       5 output_dir = f'sample_data/{dataset}'
#       7 pipeline = TrainTestSplitPipeline(model=CTGANModel)
# ----> 8 pipeline.run(
#       9     input_csv=input_csv,
#      10     output_dir=output_dir,
#      11     synthetic_dir=f'synthetic/{dataset}/ctgan',
#      12     real_test_dir=f'sample_data/{dataset}'
#      13 )
#
# File ~/Documents/Year_3/Sem_1/SIT374/KatabaticRepository/Katabatic/katabatic/pipeline/train_test_split/pipeline.py:38, in TrainTestSplitPipeline.run(self, *args, **kwargs)
#      35 split_dataset(input_csv, output_dir, *args, **kwargs)
#      37 # Train the model (may consume extra kwargs like 'config')
# ---> 38 current_model.train(output_dir, *args, **kwargs)
#      40 # Filter kwargs for evaluations to avoid unexpected params (e.g., 'config')
#      41 eval_kwargs = dict(kwargs)
#
# File ~/Documents/Year_3/Sem_1/SIT374/KatabaticRepository/Katabatic/katabatic/models/ctgan/models.py:255, in CTGANModel.train(self, data_dir, synthetic_dir, *args, **kwargs)
#     252 for _ in range(self.cfg["n_critic"]):
#     253     z = torch.randn(real_batch.size(
#     254         0), self.cfg["noise_dim"], device=self._device)
# --> 255     cond_fake_np = sample_conditions(real_batch.size(
#     256         0), self.schema, self.cond_blocks, self.empirical_probs)
#     257     cond_fake = torch.tensor(
#     258         cond_fake_np, dtype=torch.float32, device=self._device)
#     259     fake_batch = self._forward_generator(
#     260         torch, z, cond_fake).detach()
#
# File ~/Documents/Year_3/Sem_1/SIT374/KatabaticRepository/Katabatic/katabatic/models/ctgan/utils.py:179, in sample_conditions(n, schema, cond_blocks, empirical_probs, device)
#     177 if empirical_probs and name in empirical_probs:
#     178     p = empirical_probs[name]
# --> 179     k = int(np.random.choice(len(p), p=p))
#     180 else:
#     181     k = int(np.random.randint(dim))
#
# KeyboardInterrupt:
