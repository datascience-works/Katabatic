# %% [markdown]
# # SMOTE Data Generation

# %%
from katabatic.models.smote.models import SMOTEModel
from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from utils import discretize_preprocess

# %%
dataset_path = "raw_data/shuttle.csv"
output_path = "discretized_data/shuttle.csv"
discretize_preprocess(dataset_path, output_path)
# Out:
# Preprocessing: raw_data/shuttle.csv
# Saved preprocessed discrete dataset to: discretized_data/shuttle.csv

# %%
datasets = ['car', 'adult', 'magic', 'nursery', 'shuttle']

for dataset in datasets:
    input_csv = f'discretized_data/{dataset}.csv'
    output_dir = f'sample_data/{dataset}'
    
    pipeline = TrainTestSplitPipeline(model=SMOTEModel)
    pipeline.run(
        input_csv=input_csv,
        output_dir=output_dir,
        synthetic_dir=f'synthetic/{dataset}/smote',
        real_test_dir=f'sample_data/{dataset}'
    )
# Out:
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# [SMOTE] Initialising with k_neighbors=5...
# [SMOTE] Generating samples from 1382 training rows...
# [SMOTE] Generated 2490 new rows in 0.00 seconds.
# [SMOTE] Synthetic data saved:
#   X -> synthetic/car/smote/x_synth.csv
#   y -> synthetic/car/smote/y_synth.csv
#   metadata -> synthetic/car/smote/metadata.json
#
# Results saved to: Results/car/smote_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.5434
# F1 Score: 0.5888
#
# MLP:
# Accuracy: 0.9422
# F1 Score: 0.9440
#
# RF:
# Accuracy: 0.9595
# F1 Score: 0.9607
#
# XGBoost:
# Accuracy: 0.9711
# F1 Score: 0.9716
# Loaded data with shape: (32561, 15)
# Saved train/test full data
# Train size: (26048, 15), Test size: (6513, 15)
# Train label distribution:
#  class
# 0    0.759175
# 1    0.240825
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.759251
# 1    0.240749
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (26048, 14) (26048,)
# Test shape: (6513, 14) (6513,)
# [SMOTE] Initialising with k_neighbors=5...
# [SMOTE] Generating samples from 26048 training rows...
# [SMOTE] Generated 13502 new rows in 0.08 seconds.
# [SMOTE] Synthetic data saved:
#   X -> synthetic/adult/smote/x_synth.csv
#   y -> synthetic/adult/smote/y_synth.csv
#   metadata -> synthetic/adult/smote/metadata.json
#
# Results saved to: Results/adult/smote_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7551
# F1 Score: 0.7694
# AUC: 0.8439
#
# MLP:
# Accuracy: 0.8045
# F1 Score: 0.8146
# AUC: 0.8891
#
# RF:
# Accuracy: 0.8277
# F1 Score: 0.8289
# AUC: 0.8810
#
# XGBoost:
# Accuracy: 0.8451
# F1 Score: 0.8471
# AUC: 0.9052
# Loaded data with shape: (19020, 11)
# Saved train/test full data
# Train size: (15216, 11), Test size: (3804, 11)
# Train label distribution:
#  class
# 0    0.648396
# 1    0.351604
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.648265
# 1    0.351735
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (15216, 10) (15216,)
# Test shape: (3804, 10) (3804,)
# [SMOTE] Initialising with k_neighbors=5...
# [SMOTE] Generating samples from 15216 training rows...
# [SMOTE] Generated 4516 new rows in 0.05 seconds.
# [SMOTE] Synthetic data saved:
#   X -> synthetic/magic/smote/x_synth.csv
#   y -> synthetic/magic/smote/y_synth.csv
#   metadata -> synthetic/magic/smote/metadata.json
#
# Results saved to: Results/magic/smote_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7836
# F1 Score: 0.7863
# AUC: 0.8515
#
# MLP:
# Accuracy: 0.8410
# F1 Score: 0.8419
# AUC: 0.9106
#
# RF:
# Accuracy: 0.8344
# F1 Score: 0.8340
# AUC: 0.8901
#
# XGBoost:
# Accuracy: 0.8499
# F1 Score: 0.8494
# AUC: 0.9107
# Loaded data with shape: (12960, 9)
# Saved train/test full data
# Train size: (10368, 9), Test size: (2592, 9)
# Train label distribution:
#  8
# 0    0.333333
# 1    0.329186
# 3    0.312018
# 4    0.025270
# 2    0.000193
# Name: proportion, dtype: float64
# Test label distribution:
#  8
# 0    0.333333
# 1    0.329090
# 3    0.312114
# 4    0.025463
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (10368, 8) (10368,)
# Test shape: (2592, 8) (2592,)
# [SMOTE] Warning: smallest class has 2 samples.
# [SMOTE] Adjusting k_neighbors from 5 to 1.
# [SMOTE] Initialising with k_neighbors=1...
# [SMOTE] Generating samples from 10368 training rows...
# [SMOTE] Generated 6912 new rows in 0.07 seconds.
# [SMOTE] Synthetic data saved:
#   X -> synthetic/nursery/smote/x_synth.csv
#   y -> synthetic/nursery/smote/y_synth.csv
#   metadata -> synthetic/nursery/smote/metadata.json
#
# Results saved to: Results/nursery/smote_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7133
# F1 Score: 0.7228
#
# MLP:
# Accuracy: 0.9784
# F1 Score: 0.9786
#
# RF:
# Accuracy: 0.9649
# F1 Score: 0.9642
#
# XGBoost:
# Accuracy: 0.9992
# F1 Score: 0.9994
# Loaded data with shape: (58000, 10)
# Saved train/test full data
# Train size: (46400, 10), Test size: (11600, 10)
# Train label distribution:
#  class
# 0    0.785970
# 3    0.153491
# 4    0.056336
# 2    0.002953
# 1    0.000862
# 6    0.000216
# 5    0.000172
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.785948
# 3    0.153534
# 4    0.056293
# 2    0.002931
# 1    0.000862
# 6    0.000259
# 5    0.000172
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (46400, 9) (46400,)
# Test shape: (11600, 9) (11600,)
# [SMOTE] Initialising with k_neighbors=5...
# [SMOTE] Generating samples from 46400 training rows...
# [SMOTE] Generated 208883 new rows in 0.06 seconds.
# [SMOTE] Synthetic data saved:
#   X -> synthetic/shuttle/smote/x_synth.csv
#   y -> synthetic/shuttle/smote/y_synth.csv
#   metadata -> synthetic/shuttle/smote/metadata.json
#
# Results saved to: Results/shuttle/smote_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.9504
# F1 Score: 0.9536
#
# MLP:
# Accuracy: 0.9980
# F1 Score: 0.9982
#
# RF:
# Accuracy: 0.9991
# F1 Score: 0.9991
#
# XGBoost:
# Accuracy: 0.9991
# F1 Score: 0.9992
