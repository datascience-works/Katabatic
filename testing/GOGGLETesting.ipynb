# %% [markdown]
# # GOGGLE Data Generation

# %%
from katabatic.models.goggle.models import GOGGLEModel
from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from utils import discretize_preprocess
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from katabatic.models.goggle.models import GOGGLEModel
#       2 from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
#       3 from utils import discretize_preprocess
#
# ModuleNotFoundError: No module named 'katabatic.models.goggle'

# %%
dataset_path = "raw_data/shuttle.csv"
output_path = "discretized_data/shuttle.csv"
discretize_preprocess(dataset_path, output_path)
# Out:
# Preprocessing: raw_data/shuttle.csv
# Saved preprocessed discrete dataset to: discretized_data/shuttle.csv

# %%
datasets = ['car', 'adult', 'magic', 'nursery', 'shuttle']

for dataset in datasets:
    input_csv = f'discretized_data/{dataset}.csv'
    output_dir = f'sample_data/{dataset}'
    
    pipeline = TrainTestSplitPipeline(model=ARFModel)
    pipeline.run(
        input_csv=input_csv,
        output_dir=output_dir,
        synthetic_dir=f'synthetic/{dataset}/meg',
        real_test_dir=f'sample_data/{dataset}'
    )
# Out:
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# Initial accuracy is 0.38024602026049203
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/arfpy/arf.py:329: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if self.factor_cols[j]:
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/xgboost/training.py:200: UserWarning: [17:31:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/car/meg_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6994
# F1 Score: 0.5757
#
# MLP:
# Accuracy: 0.6879
# F1 Score: 0.5750
#
# RF:
# Accuracy: 0.6965
# F1 Score: 0.5889
#
# XGBoost:
# Accuracy: 0.6618
# F1 Score: 0.5896
# Loaded data with shape: (32561, 15)
# Saved train/test full data
# Train size: (26048, 15), Test size: (6513, 15)
# Train label distribution:
#  class
# 0    0.759175
# 1    0.240825
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.759251
# 1    0.240749
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (26048, 14) (26048,)
# Test shape: (6513, 14) (6513,)
# Initial accuracy is 0.9235257985257985
# Iteration number 1 reached accuracy of 0.5476044226044227.
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:611: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# Iteration number 2 reached accuracy of 0.5171030405405406.
# Iteration number 3 reached accuracy of 0.5167383292383292.
# Iteration number 4 reached accuracy of 0.5188498157248157.
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/arfpy/arf.py:329: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if self.factor_cols[j]:
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Results saved to: Results/adult/meg_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7593
# F1 Score: 0.6553
# AUC: 0.6938
#
# MLP:
# Accuracy: 0.7586
# F1 Score: 0.6601
# AUC: 0.5709
#
# RF:
# Accuracy: 0.7548
# F1 Score: 0.6589
# AUC: 0.5461
#
# XGBoost:
# Accuracy: 0.5773
# F1 Score: 0.6054
# AUC: 0.5419
# Loaded data with shape: (19020, 11)
# Saved train/test full data
# Train size: (15216, 11), Test size: (3804, 11)
# Train label distribution:
#  class
# 0    0.648396
# 1    0.351604
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.648265
# 1    0.351735
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (15216, 10) (15216,)
# Test shape: (3804, 10) (3804,)
# Initial accuracy is 0.8742442166140905
# Iteration number 1 reached accuracy of 0.4723646161934805.
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/arfpy/arf.py:329: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if self.factor_cols[j]:
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Results saved to: Results/magic/meg_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6483
# F1 Score: 0.5099
# AUC: 0.6398
#
# MLP:
# Accuracy: 0.6548
# F1 Score: 0.5415
# AUC: 0.4960
#
# RF:
# Accuracy: 0.5965
# F1 Score: 0.5308
# AUC: 0.5231
#
# XGBoost:
# Accuracy: 0.5413
# F1 Score: 0.5510
# AUC: 0.4984
# Loaded data with shape: (12960, 9)
# Saved train/test full data
# Train size: (10368, 9), Test size: (2592, 9)
# Train label distribution:
#  8
# 0    0.333333
# 1    0.329186
# 3    0.312018
# 4    0.025270
# 2    0.000193
# Name: proportion, dtype: float64
# Test label distribution:
#  8
# 0    0.333333
# 1    0.329090
# 3    0.312114
# 4    0.025463
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (10368, 8) (10368,)
# Test shape: (2592, 8) (2592,)
# Initial accuracy is 0.3997395833333333
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/arfpy/arf.py:329: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if self.factor_cols[j]:
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/xgboost/training.py:200: UserWarning: [17:33:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/nursery/meg_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.3125
# F1 Score: 0.2966
#
# MLP:
# Accuracy: 0.3241
# F1 Score: 0.3184
#
# RF:
# Accuracy: 0.3515
# F1 Score: 0.3451
#
# XGBoost:
# Accuracy: 0.3708
# F1 Score: 0.3651
# Loaded data with shape: (58000, 10)
# Saved train/test full data
# Train size: (46400, 10), Test size: (11600, 10)
# Train label distribution:
#  class
# 0    0.785970
# 3    0.153491
# 4    0.056336
# 2    0.002953
# 1    0.000862
# 6    0.000216
# 5    0.000172
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.785948
# 3    0.153534
# 4    0.056293
# 2    0.002931
# 1    0.000862
# 6    0.000259
# 5    0.000172
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (46400, 9) (46400,)
# Test shape: (11600, 9) (11600,)
# Initial accuracy is 0.984396551724138
# Iteration number 1 reached accuracy of 0.5386637931034483.
# Iteration number 2 reached accuracy of 0.4617241379310345.
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/arfpy/arf.py:329: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if self.factor_cols[j]:
# /Users/zachariahchristie/Library/Caches/pypoetry/virtualenvs/katabatic-xSO1op2T-py3.11/lib/python3.11/site-packages/xgboost/training.py:200: UserWarning: [17:34:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/shuttle/meg_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7859
# F1 Score: 0.6917
#
# MLP:
# Accuracy: 0.7859
# F1 Score: 0.6917
#
# RF:
# Accuracy: 0.7602
# F1 Score: 0.6892
#
# XGBoost:
# Accuracy: 0.7854
# F1 Score: 0.6915
